# %%
import pandas as pd

# %%
df1=pd.read_csv('./../data/ai-productivity-data/user_level_ai_adoption.csv')

# %%
df2=pd.read_csv('./../data/ai-productivity-data/ai_adoption_productivity_2021_2026.csv')

# %%
df1.head()
# Out:
#         User_ID              Industry              Job_Role       Location  \
# 0  USR-690F519F  Software Development     Software Engineer         Europe
# 1  USR-72A07ABB  Software Development     Software Engineer  North America
# 2  USR-CBCEAA19               Finance            Accountant   Asia-Pacific
# 3  USR-03B7DC34            Healthcare        Clinical Admin  North America
# 4  USR-CA8308D1             Marketing  Social Media Manager   Asia-Pacific
#
#    Experience_Years     Primary_AI_Tool  Daily_Token_Usage  \
# 0                13    ChatGPT (OpenAI)              10640
# 1                 9  Claude (Anthropic)               8535
# 2                21  Claude (Anthropic)               9585
# 3                20          Perplexity               7094
# 4                14    ChatGPT (OpenAI)               9277
#
#    Tasks_Automated_Per_Week  Productivity_Gain_Percent Adoption_Date
# 0                         2                       19.3    2023-02-28
# ...

# %%
df2.head()
# Out:
#   YearMonth              Industry                          Primary Use Case  \
# 0   2021-01  Software Development               Code Generation & Debugging
# 1   2021-01   Marketing & Content                         Copywriting & SEO
# 2   2021-01      Customer Support               Automated Chatbots & Triage
# 3   2021-01            Healthcare  Medical Records & Diagnostics Assistance
# 4   2021-01             Education                Lesson Planning & Tutoring
#
#    Global Active Users (Millions)  Average Tokens/User/Day  \
# 0                            0.49                     5248
# 1                            1.24                     2141
# 2                            0.83                     3206
# 3                            0.10                      937
# 4                            0.39                     1594
#
#    Productivity Gain (%)
# 0                    4.9
# 1                    9.7
# 2                   15.5
# 3                    1.9
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   User_ID                    15000 non-null  object
#  1   Industry                   15000 non-null  object
#  2   Job_Role                   15000 non-null  object
#  3   Location                   15000 non-null  object
#  4   Experience_Years           15000 non-null  int64
#  5   Primary_AI_Tool            15000 non-null  object
#  6   Daily_Token_Usage          15000 non-null  int64
#  7   Tasks_Automated_Per_Week   15000 non-null  int64
#  8   Productivity_Gain_Percent  15000 non-null  float64
#  9   Adoption_Date              15000 non-null  object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 1.1+ MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 402 entries, 0 to 401
# Data columns (total 6 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   YearMonth                       402 non-null    object
#  1   Industry                        402 non-null    object
#  2   Primary Use Case                402 non-null    object
#  3   Global Active Users (Millions)  402 non-null    float64
#  4   Average Tokens/User/Day         402 non-null    int64
#  5   Productivity Gain (%)           402 non-null    float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 19.0+ KB

# %%
df1.describe()
# Out:
#        Experience_Years  Daily_Token_Usage  Tasks_Automated_Per_Week  \
# count      15000.000000       15000.000000              15000.000000
# mean          13.013400        8958.312200                  1.913267
# std            7.215642        8449.890624                  1.176196
# min            1.000000         411.000000                  1.000000
# 25%            7.000000        3049.000000                  1.000000
# 50%           13.000000        7336.000000                  2.000000
# 75%           19.000000       11740.250000                  3.000000
# max           25.000000       58989.000000                 12.000000
#
#        Productivity_Gain_Percent
# count               15000.000000
# mean                   11.215827
# std                    11.578100
# min                     0.300000
# 25%                     3.600000
# 50%                     8.100000
# 75%                    14.800000
# max                    84.900000

# %%
df2.describe()
# Out:
#        Global Active Users (Millions)  Average Tokens/User/Day  \
# count                      402.000000               402.000000
# mean                        18.089229             11732.104478
# std                         26.138400             16189.762385
# min                          0.100000               935.000000
# 25%                          1.007500              3287.750000
# 50%                          5.240000              6456.000000
# 75%                         29.170000             12103.750000
# max                        103.970000            100750.000000
#
#        Productivity Gain (%)
# count             402.000000
# mean               41.005224
# std                15.473256
# min                 1.900000
# 25%                30.225000
# 50%                41.300000
# 75%                52.300000
# max                71.100000

# %%
df1.isnull().sum()
# Out:
# User_ID                      0
# Industry                     0
# Job_Role                     0
# Location                     0
# Experience_Years             0
# Primary_AI_Tool              0
# Daily_Token_Usage            0
# Tasks_Automated_Per_Week     0
# Productivity_Gain_Percent    0
# Adoption_Date                0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# YearMonth                         0
# Industry                          0
# Primary Use Case                  0
# Global Active Users (Millions)    0
# Average Tokens/User/Day           0
# Productivity Gain (%)             0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df2.duplicated().sum()
# Out:
# 0
