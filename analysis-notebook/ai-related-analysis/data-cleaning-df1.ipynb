# %%
import pandas as pd

# %%
df1=pd.read_csv('./../data/ai-productivity-data/user_level_ai_adoption.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   User_ID                    15000 non-null  object
#  1   Industry                   15000 non-null  object
#  2   Job_Role                   15000 non-null  object
#  3   Location                   15000 non-null  object
#  4   Experience_Years           15000 non-null  int64
#  5   Primary_AI_Tool            15000 non-null  object
#  6   Daily_Token_Usage          15000 non-null  int64
#  7   Tasks_Automated_Per_Week   15000 non-null  int64
#  8   Productivity_Gain_Percent  15000 non-null  float64
#  9   Adoption_Date              15000 non-null  object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 1.1+ MB

# %%
df1.head()
# Out:
#         User_ID              Industry              Job_Role       Location  \
# 0  USR-690F519F  Software Development     Software Engineer         Europe
# 1  USR-72A07ABB  Software Development     Software Engineer  North America
# 2  USR-CBCEAA19               Finance            Accountant   Asia-Pacific
# 3  USR-03B7DC34            Healthcare        Clinical Admin  North America
# 4  USR-CA8308D1             Marketing  Social Media Manager   Asia-Pacific
#
#    Experience_Years     Primary_AI_Tool  Daily_Token_Usage  \
# 0                13    ChatGPT (OpenAI)              10640
# 1                 9  Claude (Anthropic)               8535
# 2                21  Claude (Anthropic)               9585
# 3                20          Perplexity               7094
# 4                14    ChatGPT (OpenAI)               9277
#
#    Tasks_Automated_Per_Week  Productivity_Gain_Percent Adoption_Date
# 0                         2                       19.3    2023-02-28
# ...

# %%
df1['Adoption_Date']=pd.to_datetime(df1['Adoption_Date']);
df1['Adoption_Date'].head()
# Out:
# 0   2023-02-28
# 1   2023-08-17
# 2   2023-11-02
# 3   2025-06-06
# 4   2023-04-03
# Name: Adoption_Date, dtype: datetime64[ns]

# %%
df1=df1.sort_values('Adoption_Date').reset_index(drop=True)

# %%
df1.head()
# Out:
#         User_ID              Industry           Job_Role       Location  \
# 0  USR-155B3993             Education            Student   Asia-Pacific
# 1  USR-8545095D  Software Development          QA Tester         Europe
# 2  USR-85C719CE  Software Development  Software Engineer  North America
# 3  USR-D3BB4628             Education            Teacher   Asia-Pacific
# 4  USR-2C474BB8     Creative & Design       Video Editor  North America
#
#    Experience_Years     Primary_AI_Tool  Daily_Token_Usage  \
# 0                 1  Claude (Anthropic)               4550
# 1                18  Claude (Anthropic)              15953
# 2                21  Claude (Anthropic)               3498
# 3                22  Claude (Anthropic)              15637
# 4                16  Claude (Anthropic)              11375
#
#    Tasks_Automated_Per_Week  Productivity_Gain_Percent Adoption_Date
# 0                         1                        6.9    2021-01-01
# ...

# %%
df1['Productivity_Gain_Percent'].unique()
# Out:
# array([ 6.9, 28.8,  4.9, 14.3, 23.9, 12.9, 19. ,  6.5,  3. , 13.1,  5.7,
#         3.4,  2.8,  6. , 12.8, 12.1,  1. ,  9.9, 20.3, 11.3,  2. ,  7.6,
#        21.6,  7.8, 48.3, 33.3,  4. ,  7. , 27. ,  8. , 13.8, 51.6,  6.4,
#        13. ,  1.5,  1.1,  9.8,  5. ,  2.4, 36.3, 10.3,  7.4,  3.2,  3.9,
#        24.6, 11.9, 21.4, 11. ,  8.2,  2.9,  1.6, 20.1, 18.9, 15.5,  5.5,
#        10.4,  7.9,  2.6,  8.3, 10.7, 10. , 24.2,  3.3, 10.9, 25.1,  7.7,
#        11.2, 14.5, 10.1,  0.6, 21.1,  9. , 17.1, 25. , 16.3,  4.4, 12. ,
#         6.6,  8.6, 11.7,  1.9,  4.5, 21.5,  1.4, 48.1,  2.7,  9.2,  5.3,
#         8.7, 19.3,  8.9,  5.2,  3.6, 15. , 16.5,  7.2,  7.3, 22.7,  2.2,
#        13.6, 23.2, 14.2,  2.5, 11.4, 11.8,  6.8,  4.3, 16.8, 19.1,  8.8,
#         0.8, 18.2, 47.9,  9.7,  5.8, 17.3,  7.5,  6.3, 23.6, 10.6, 13.2,
#        35.2, 11.5, 38.1,  1.2,  1.7,  3.1,  5.4, 14.6, 11.1,  6.2, 14.1,
#         4.7,  9.5, 40.3,  4.1,  7.1,  8.1, 10.8, 23.5, 32.5,  5.9, 24. ,
# ...

# %%
df1['Adoption_Date'].unique()
# Out:
# <DatetimeArray>
# ['2021-01-01 00:00:00', '2021-01-02 00:00:00', '2021-01-03 00:00:00',
#  '2021-01-04 00:00:00', '2021-01-05 00:00:00', '2021-01-06 00:00:00',
#  '2021-01-07 00:00:00', '2021-01-09 00:00:00', '2021-01-10 00:00:00',
#  '2021-01-11 00:00:00',
#  ...
#  '2026-06-21 00:00:00', '2026-06-22 00:00:00', '2026-06-23 00:00:00',
#  '2026-06-24 00:00:00', '2026-06-25 00:00:00', '2026-06-26 00:00:00',
#  '2026-06-27 00:00:00', '2026-06-28 00:00:00', '2026-06-29 00:00:00',
#  '2026-06-30 00:00:00']
# Length: 1940, dtype: datetime64[ns]

# %%
df1.head()
# Out:
#         User_ID              Industry           Job_Role       Location  \
# 0  USR-155B3993             Education            Student   Asia-Pacific
# 1  USR-8545095D  Software Development          QA Tester         Europe
# 2  USR-85C719CE  Software Development  Software Engineer  North America
# 3  USR-D3BB4628             Education            Teacher   Asia-Pacific
# 4  USR-2C474BB8     Creative & Design       Video Editor  North America
#
#    Experience_Years     Primary_AI_Tool  Daily_Token_Usage  \
# 0                 1  Claude (Anthropic)               4550
# 1                18  Claude (Anthropic)              15953
# 2                21  Claude (Anthropic)               3498
# 3                22  Claude (Anthropic)              15637
# 4                16  Claude (Anthropic)              11375
#
#    Tasks_Automated_Per_Week  Productivity_Gain_Percent Adoption_Date
# 0                         1                        6.9    2021-01-01
# ...

# %%
##df1.to_csv('./../data/ai-productivity-data/cleaned_user_level_ai_adoption.csv', index=False)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   User_ID                    15000 non-null  object
#  1   Industry                   15000 non-null  object
#  2   Job_Role                   15000 non-null  object
#  3   Location                   15000 non-null  object
#  4   Experience_Years           15000 non-null  int64
#  5   Primary_AI_Tool            15000 non-null  object
#  6   Daily_Token_Usage          15000 non-null  int64
#  7   Tasks_Automated_Per_Week   15000 non-null  int64
#  8   Productivity_Gain_Percent  15000 non-null  float64
#  9   Adoption_Date              15000 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(3), object(5)
# memory usage: 1.1+ MB
